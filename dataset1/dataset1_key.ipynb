# %%
import numpy as np
import matplotlib.pyplot as plt
import csv
import time

# %%
start_time = time.time()
cleartext = []

base_path_python = './'

with open(base_path_python + 'cleartext.txt') as csvfile:
    reader = csv.reader(csvfile, delimiter=' ')
    for element in reader:
        cleartext.append(element)
cleartext = [[int(num) for num in sublist] for sublist in cleartext]

# %%
# https://femionewin.medium.com/aes-encryption-with-python-step-by-step-3e3ab0b0fd6c
# First hamming weight to plot it later
sbox = [
    ]

model = []
for x in range(150): # For all the cleartexts
    trace = []
    for y in range(256): # For all the keys
        for z in range(16): # For all the positions
            xor = (cleartext[x][z])^y
            HW = bin(sbox[xor]).count('1') # SBOX + count the number of 1s (Hamming weight)
        trace.append(HW)
    model.append(trace)

# %%
plt.plot(np.arange(1,257,1), model[0])
plt.xlabel('Sample')
plt.ylabel('Power consumption')
plt.show()

# %%
key = []

for z in range(16): # z is the byte of the key we are analyzing
    trace_byte = []
    print("Analyzing byte "+str(z))

    with open(base_path_python + 'trace'+str(z)+'.txt') as csvfile:
        reader = csv.reader(csvfile, delimiter=' ')
        for element in reader:
            element.pop()
            trace_byte.append(element)
    trace_byte = [[float(num) for num in sublist] for sublist in trace_byte]

    model = []

    for x in range(150): # For all the cleartexts
        trace = []
        for y in range(256): # For all the keys
            xor = (cleartext[x][z])^(y)
            HW = bin(sbox[xor]).count('1') # SBOX + count the number of 1s (Hamming weight)
            trace.append(HW)
        model.append(trace)

    model_transposed = []
    for i in range(256):
            model_i = []
            for j in range(150):
                model_i.append(model[j][i])
            model_transposed.append(model_i)
    
    #CPA
    max = 0
    key_i = 0
    
    for k in range(50000):
        corr_i = []
        trace_i = []
        for j in range(150):
            trace_i.append(trace_byte[j][k])

        for i in range(256):

            corr0 = np.corrcoef(trace_i, model_transposed[i])

            value = abs(corr0[0][1])
            if (value >= 0.7):
                print("       Potential match at t = "+str(k)+" with key = "+str(i)+" and correlation of "+str(value))
                if (value >= max): # We store the value with the highest correlation (i.e. the key)
                    max = value
                    key_i = i
    
    key.append(key_i)

print("The key of dataset1 is ", key)
# Out:
# Analyzing byte 0
#        Potential match at t = 29235 with key = 65 and correlation of 0.7298723439186945
#        Potential match at t = 29535 with key = 65 and correlation of 0.7222878247145803
#        Potential match at t = 32035 with key = 65 and correlation of 0.7578876243519199
#        Potential match at t = 32036 with key = 65 and correlation of 0.7063796764046906
#        Potential match at t = 32040 with key = 65 and correlation of 0.7150987913216211
#        Potential match at t = 32335 with key = 65 and correlation of 0.7916596130387974
#        Potential match at t = 32336 with key = 65 and correlation of 0.7248134167240687
#        Potential match at t = 32340 with key = 65 and correlation of 0.7292634942009127
#        Potential match at t = 40335 with key = 65 and correlation of 0.8159225192371423
#        Potential match at t = 40336 with key = 65 and correlation of 0.7263197887031844
#        Potential match at t = 40340 with key = 65 and correlation of 0.7776972085587953
#        Potential match at t = 46435 with key = 65 and correlation of 0.8335713262662695
#        Potential match at t = 47135 with key = 65 and correlation of 0.7324233428475133
# Analyzing byte 1
#        Potential match at t = 29235 with key = 117 and correlation of 0.7255972079790545
#        Potential match at t = 29236 with key = 117 and correlation of 0.7075381578188414
#        Potential match at t = 32035 with key = 117 and correlation of 0.7669218262426013
#        Potential match at t = 32335 with key = 117 and correlation of 0.7777452305884666
#        Potential match at t = 32340 with key = 117 and correlation of 0.7019937718847866
#        Potential match at t = 40335 with key = 117 and correlation of 0.7395789740966794
#        Potential match at t = 46435 with key = 117 and correlation of 0.7703993828298404
# Analyzing byte 2
#        Potential match at t = 29235 with key = 115 and correlation of 0.7158188845824954
#        Potential match at t = 29236 with key = 115 and correlation of 0.7243822759058987
#        Potential match at t = 29535 with key = 115 and correlation of 0.7748909753817791
#        Potential match at t = 32035 with key = 115 and correlation of 0.7662865816332618
#        Potential match at t = 32036 with key = 115 and correlation of 0.7382916781729096
#        Potential match at t = 32335 with key = 115 and correlation of 0.7836816570433455
#        Potential match at t = 32336 with key = 115 and correlation of 0.7029390940093599
#        Potential match at t = 40335 with key = 115 and correlation of 0.7446827122849706
#        Potential match at t = 40340 with key = 115 and correlation of 0.709141153995957
#        Potential match at t = 46435 with key = 115 and correlation of 0.8188099336649544
#        Potential match at t = 47135 with key = 115 and correlation of 0.7146703654080825
# Analyzing byte 3
#        Potential match at t = 29236 with key = 116 and correlation of 0.7247330259163143
#        Potential match at t = 29535 with key = 116 and correlation of 0.7852188920616417
#        Potential match at t = 32035 with key = 116 and correlation of 0.76288089332476
#        Potential match at t = 32036 with key = 116 and correlation of 0.7060488683105789
#        Potential match at t = 32335 with key = 116 and correlation of 0.8220807429519548
#        Potential match at t = 32336 with key = 116 and correlation of 0.7034732947619641
#        Potential match at t = 32339 with key = 116 and correlation of 0.7474307230641817
#        Potential match at t = 32340 with key = 116 and correlation of 0.7646224819588308
#        Potential match at t = 40335 with key = 116 and correlation of 0.7530937015081293
#        Potential match at t = 40340 with key = 116 and correlation of 0.7012214986283282
#        Potential match at t = 46435 with key = 116 and correlation of 0.8297999991373642
#        Potential match at t = 47135 with key = 116 and correlation of 0.7229498749195296
# Analyzing byte 4
#        Potential match at t = 29235 with key = 114 and correlation of 0.7351322529013036
#        Potential match at t = 29535 with key = 114 and correlation of 0.7788801382392996
#        Potential match at t = 32035 with key = 114 and correlation of 0.7503273526950126
#        Potential match at t = 32036 with key = 114 and correlation of 0.7201687188782926
#        Potential match at t = 32041 with key = 114 and correlation of 0.7244811537090863
#        Potential match at t = 32335 with key = 114 and correlation of 0.8073899643214811
#        Potential match at t = 32336 with key = 114 and correlation of 0.7502615758326119
#        Potential match at t = 32340 with key = 114 and correlation of 0.708351223908934
#        Potential match at t = 40335 with key = 114 and correlation of 0.8275674727852927
#        Potential match at t = 40336 with key = 114 and correlation of 0.7395772238826439
#        Potential match at t = 40340 with key = 114 and correlation of 0.7401676819645793
#        Potential match at t = 46435 with key = 114 and correlation of 0.8033109436678526
#        Potential match at t = 47135 with key = 114 and correlation of 0.7710500673672133
# Analyzing byte 5
#        Potential match at t = 29235 with key = 97 and correlation of 0.754699360368529
#        Potential match at t = 29236 with key = 97 and correlation of 0.7452576931685168
#        Potential match at t = 29535 with key = 97 and correlation of 0.7805353881945573
#        Potential match at t = 32035 with key = 97 and correlation of 0.8099067201027846
#        Potential match at t = 32036 with key = 97 and correlation of 0.7912754569394835
#        Potential match at t = 32335 with key = 97 and correlation of 0.8148447517047575
#        Potential match at t = 32336 with key = 97 and correlation of 0.7160622767101389
#        Potential match at t = 32340 with key = 97 and correlation of 0.7899131786496812
#        Potential match at t = 32341 with key = 97 and correlation of 0.7017631100036983
#        Potential match at t = 40335 with key = 97 and correlation of 0.8306098955142728
#        Potential match at t = 40339 with key = 97 and correlation of 0.7152489339462225
#        Potential match at t = 40340 with key = 97 and correlation of 0.7322657826465735
#        Potential match at t = 46435 with key = 97 and correlation of 0.8223411229141104
#        Potential match at t = 46735 with key = 97 and correlation of 0.7049536434386496
#        Potential match at t = 47135 with key = 97 and correlation of 0.8016297462229234
# Analyzing byte 6
#        Potential match at t = 29236 with key = 108 and correlation of 0.7181430055291592
#        Potential match at t = 29535 with key = 108 and correlation of 0.7248392826583563
#        Potential match at t = 32035 with key = 108 and correlation of 0.7841810015339367
#        Potential match at t = 32036 with key = 108 and correlation of 0.735575674744046
#        Potential match at t = 32335 with key = 108 and correlation of 0.8245457260244137
#        Potential match at t = 32336 with key = 108 and correlation of 0.751780661607228
#        Potential match at t = 32339 with key = 108 and correlation of 0.7446003257653915
#        Potential match at t = 32340 with key = 108 and correlation of 0.7038326832282931
#        Potential match at t = 40335 with key = 108 and correlation of 0.8022650213512803
#        Potential match at t = 40339 with key = 108 and correlation of 0.7083518338344222
#        Potential match at t = 46435 with key = 108 and correlation of 0.8257118813864766
#        Potential match at t = 46436 with key = 108 and correlation of 0.7210208821780703
#        Potential match at t = 46440 with key = 108 and correlation of 0.7167654944640084
#        Potential match at t = 47135 with key = 108 and correlation of 0.7491745951070387
# Analyzing byte 7
#        Potential match at t = 29235 with key = 111 and correlation of 0.7195655186166002
#        Potential match at t = 32035 with key = 111 and correlation of 0.7097308567424775
#        Potential match at t = 32036 with key = 111 and correlation of 0.7127531382186129
#        Potential match at t = 32335 with key = 111 and correlation of 0.7994504892150329
#        Potential match at t = 32339 with key = 111 and correlation of 0.7205268901476478
#        Potential match at t = 40335 with key = 111 and correlation of 0.7205222129111646
#        Potential match at t = 46435 with key = 111 and correlation of 0.7851853927928365
#        Potential match at t = 47135 with key = 111 and correlation of 0.7339288564180564
# Analyzing byte 8
#        Potential match at t = 29235 with key = 112 and correlation of 0.7030038576985018
#        Potential match at t = 29535 with key = 112 and correlation of 0.7383988296618634
#        Potential match at t = 32035 with key = 112 and correlation of 0.7380105228629923
#        Potential match at t = 32036 with key = 112 and correlation of 0.781552445591291
#        Potential match at t = 32040 with key = 112 and correlation of 0.7247277047581973
#        Potential match at t = 32335 with key = 112 and correlation of 0.8019333415853918
#        Potential match at t = 32340 with key = 112 and correlation of 0.7100099631833763
#        Potential match at t = 40335 with key = 112 and correlation of 0.7766124498256325
#        Potential match at t = 40339 with key = 112 and correlation of 0.7266112889029269
#        Potential match at t = 40340 with key = 112 and correlation of 0.7305636219180586
#        Potential match at t = 46435 with key = 112 and correlation of 0.8088749303571012
#        Potential match at t = 46735 with key = 112 and correlation of 0.7148357887500815
#        Potential match at t = 47135 with key = 112 and correlation of 0.7320125112667658
# Analyzing byte 9
#        Potential match at t = 29235 with key = 105 and correlation of 0.7769754704716805
#        Potential match at t = 29535 with key = 105 and correlation of 0.7926775069090508
#        Potential match at t = 32035 with key = 105 and correlation of 0.7649989002274905
#        Potential match at t = 32036 with key = 105 and correlation of 0.7066095281902496
#        Potential match at t = 32335 with key = 105 and correlation of 0.8109758080146352
#        Potential match at t = 32336 with key = 105 and correlation of 0.7305954250972008
#        Potential match at t = 32339 with key = 105 and correlation of 0.7093242598871957
#        Potential match at t = 32340 with key = 105 and correlation of 0.7317002671049664
#        Potential match at t = 40335 with key = 105 and correlation of 0.7888873736153502
#        Potential match at t = 40340 with key = 105 and correlation of 0.7001738040622906
#        Potential match at t = 46435 with key = 105 and correlation of 0.8354629186292936
#        Potential match at t = 47135 with key = 105 and correlation of 0.7122663514075791
# Analyzing byte 10
#        Potential match at t = 32035 with key = 116 and correlation of 0.752795195806047
#        Potential match at t = 32335 with key = 116 and correlation of 0.7741129238113447
#        Potential match at t = 32339 with key = 116 and correlation of 0.7075782221848689
#        Potential match at t = 40335 with key = 116 and correlation of 0.7088865768362894
#        Potential match at t = 40340 with key = 116 and correlation of 0.7089550416897796
#        Potential match at t = 46435 with key = 116 and correlation of 0.8301106191789581
# Analyzing byte 11
#        Potential match at t = 29235 with key = 104 and correlation of 0.7978593788447486
#        Potential match at t = 29236 with key = 104 and correlation of 0.713459431630833
#        Potential match at t = 29535 with key = 104 and correlation of 0.7243089232836013
#        Potential match at t = 32035 with key = 104 and correlation of 0.7764374405000228
#        Potential match at t = 32036 with key = 104 and correlation of 0.7386096649705793
#        Potential match at t = 32040 with key = 104 and correlation of 0.7017652879106911
#        Potential match at t = 32335 with key = 104 and correlation of 0.8417055864884966
#        Potential match at t = 32336 with key = 104 and correlation of 0.7313191397028898
#        Potential match at t = 32339 with key = 104 and correlation of 0.7072288895816018
#        Potential match at t = 32340 with key = 104 and correlation of 0.7445328146858458
#        Potential match at t = 40335 with key = 104 and correlation of 0.730063388087036
#        Potential match at t = 46435 with key = 104 and correlation of 0.8442536991809212
#        Potential match at t = 47135 with key = 104 and correlation of 0.7020665405164478
# Analyzing byte 12
#        Potential match at t = 29235 with key = 101 and correlation of 0.8169735088528686
#        Potential match at t = 29236 with key = 101 and correlation of 0.7270726327612744
#        Potential match at t = 29535 with key = 101 and correlation of 0.7846111022377376
#        Potential match at t = 32035 with key = 101 and correlation of 0.8128864974944037
#        Potential match at t = 32036 with key = 101 and correlation of 0.7072256695814242
#        Potential match at t = 32335 with key = 101 and correlation of 0.820220226103924
#        Potential match at t = 32336 with key = 101 and correlation of 0.7925987304065857
#        Potential match at t = 32339 with key = 101 and correlation of 0.7437830920691433
#        Potential match at t = 32340 with key = 101 and correlation of 0.7653287621334787
#        Potential match at t = 32341 with key = 101 and correlation of 0.7165862093443226
#        Potential match at t = 40335 with key = 101 and correlation of 0.8765258328216982
#        Potential match at t = 40336 with key = 101 and correlation of 0.7539164592764429
#        Potential match at t = 40339 with key = 101 and correlation of 0.7228667708869114
#        Potential match at t = 46435 with key = 101 and correlation of 0.8250971950898672
#        Potential match at t = 46735 with key = 101 and correlation of 0.7379656020635955
#        Potential match at t = 47135 with key = 101 and correlation of 0.8067260536213817
# Analyzing byte 13
#        Potential match at t = 29235 with key = 99 and correlation of 0.75958381721876
#        Potential match at t = 29535 with key = 99 and correlation of 0.7147612992696623
#        Potential match at t = 32035 with key = 99 and correlation of 0.7627075912960455
#        Potential match at t = 32036 with key = 99 and correlation of 0.7496462325245257
#        Potential match at t = 32335 with key = 99 and correlation of 0.8456428423068313
#        Potential match at t = 32336 with key = 99 and correlation of 0.713131972176824
#        Potential match at t = 32340 with key = 99 and correlation of 0.7242484836285913
#        Potential match at t = 40335 with key = 99 and correlation of 0.8035897942370358
#        Potential match at t = 40339 with key = 99 and correlation of 0.7133122384340777
#        Potential match at t = 46435 with key = 99 and correlation of 0.7990750651846705
#        Potential match at t = 46735 with key = 99 and correlation of 0.7197515957259537
#        Potential match at t = 47135 with key = 99 and correlation of 0.7411661820872054
# Analyzing byte 14
#        Potential match at t = 29535 with key = 117 and correlation of 0.7105533863380803
#        Potential match at t = 32035 with key = 117 and correlation of 0.7166121422126802
#        Potential match at t = 32036 with key = 117 and correlation of 0.7443126252730428
#        Potential match at t = 32335 with key = 117 and correlation of 0.7647321164041316
#        Potential match at t = 40335 with key = 117 and correlation of 0.7525999373546296
#        Potential match at t = 46435 with key = 117 and correlation of 0.7960506532022367
#        Potential match at t = 47135 with key = 117 and correlation of 0.7112715396294439
# Analyzing byte 15
#        Potential match at t = 29235 with key = 115 and correlation of 0.723016496954231
#        Potential match at t = 29236 with key = 115 and correlation of 0.71795168197276
#        Potential match at t = 29535 with key = 115 and correlation of 0.7669713484865428
#        Potential match at t = 32035 with key = 115 and correlation of 0.7743621782351652
#        Potential match at t = 32335 with key = 115 and correlation of 0.7895720330160588
#        Potential match at t = 32336 with key = 115 and correlation of 0.7245179134711737
#        Potential match at t = 32340 with key = 115 and correlation of 0.7538769968559556
#        Potential match at t = 40335 with key = 115 and correlation of 0.7235375313285378
#        Potential match at t = 46435 with key = 115 and correlation of 0.7909815734474338
#        Potential match at t = 46440 with key = 115 and correlation of 0.7192071900872351
#        Potential match at t = 47135 with key = 115 and correlation of 0.7455163433666563
# The key of dataset1 is  [65, 117, 115, 116, 114, 97, 108, 111, 112, 105, 116, 104, 101, 99, 117, 115]

# %%
checksum = sum(key)
print("Checksum:",checksum)
if checksum == 1712:
    print("Checksum is correct")
# Out:
# Checksum: 1712
# Checksum is correct

# %%
elapsed_time = time.time() - start_time
print('Execution time:', time.strftime("%H:%M:%S", time.gmtime(elapsed_time)))
# Out:
# Execution time: 09:10:26
